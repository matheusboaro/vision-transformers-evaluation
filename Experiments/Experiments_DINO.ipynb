# %% [markdown]
# # Imports and Installations
# - Kaggle package
# - Drive Connection
# - Download base

# %%
# !pip install timm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting timm
#   Downloading timm-0.5.4-py3-none-any.whl (431 kB)
#      |████████████████████████████████| 431 kB 4.8 MB/s
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from timm) (0.12.0+cu113)
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.7/dist-packages (from timm) (1.11.0+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.4->timm) (4.1.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (1.21.6)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (7.1.2)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (3.0.4)
# Installing collected packages: timm
# Successfully installed timm-0.5.4

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install kaggle
! mkdir ~/.kaggle}
# !cp /content/drive/MyDrive/kaggle.json ~/.kaggle/kaggle.json
! chmod 600 ~/.kaggle/kaggle.json
! kaggle datasets download xhlulu/140k-real-and-fake-faces
! unzip '140k-real-and-fake-faces.zip';

# %%
from json import load
import torch
import numpy as np
from torchvision.datasets import ImageFolder
from torchvision.transforms import ToTensor,Compose, Resize, Normalize
from torch.utils.data.dataloader import DataLoader
from torch.utils.data import random_split
from torch import nn
import torch.nn.functional as F
from PIL import Image
from sklearn.metrics import confusion_matrix,precision_recall_fscore_support
import pandas as pd
import seaborn as sn

# %% [markdown]
# # Auxiliary codes
# - Detect GPU
# - Load base
# - Calculate metrics
# - Evaluate model

# %%
def get_default_device():

    if torch.cuda.is_available():
        return torch.device("cuda")
    else:
        return torch.device("cpu")

def to_device(data,device):
    if isinstance(data, (list,tuple)):
        return [to_device(x,device) for x in data]

    return data.to(device, non_blocking=True)

class DeviceDataLoader():

    def __init__(self,dl,device):
        self.dl = dl
        self.device = device

    def __iter__(self):
        for b in self.dl:
            yield to_device(b,self.device)

    def __len__(self):
        return len(self.dl)

# %%
def load_data(path,train_rate,batch_size,test=False):
    NORMALIZE_MEAN = (0.5, 0.5, 0.5)
    NORMALIZE_STD = (0.5, 0.5, 0.5)
    transform = Compose([
              Resize(size=(224, 224)),
              ToTensor(),
              Normalize(NORMALIZE_MEAN, NORMALIZE_STD),
              ])
    
    #transform = Compose([Resize(size=(384, 384)), ToTensor()])
    dataset_train = ImageFolder(path+"/train", transform=transform)
    dataset_test = ImageFolder(path+"/test", transform=transform)
    dataset_valid =ImageFolder(path+"/valid", transform=transform)

    #train_size = int( len(dataset)* train_rate)
    #test_size = len(dataset) - train_size

    #train_ds,test_ds =  random_split(dataset,[train_size,test_size])

    train_dl = DataLoader(dataset_train,batch_size,shuffle=True)
    test_dl = DataLoader(dataset_test,batch_size)
    valid_dl = DataLoader(dataset_valid,batch_size)
    
    
    return train_dl,test_dl,valid_dl

def accuracy(outputs, labels):
    _,preds = torch.max(outputs,dim = 1)
    return torch.tensor(torch.sum(preds==labels).item() / len(preds))
def validation_epoch_end(outputs):
        batch_loss = [x['val_loss'] for x in outputs]
        epoch_loss = torch.stack(batch_loss).mean()
        batch_acc = [x['val_acc'] for x in outputs]
        epoch_acc = torch.stack(batch_acc).mean()

        return {"val_loss":epoch_loss.item(),'val_acc':epoch_acc.item()}
def epoch_end( epoch, result):
        print("Epoch [{}], val_loss: {:.4f}, val_acc: {:.4f}".format(
            epoch, result['val_loss'], result['val_acc']))

# %%
@torch.no_grad()
def evaluate(model, val_loader):
    model.eval()
    outputs =[]

    y_pred = []
    y_true = []
    for batch in val_loader:

        out = model(batch[0])
        y_pred.extend(torch.max(out,dim = 1)[1].data.cpu().numpy())

        labels = batch[1].data.cpu().numpy()
        y_true.extend(labels)

        loss = F.cross_entropy(out,batch[1])
        acc = accuracy(out,batch[1])
        outputs.append({'val_loss': loss.detach(), "val_acc":acc})
        #break
    return validation_epoch_end(outputs), y_true,y_pred

# %%
train,test,valid = load_data('/content/real_vs_fake/real-vs-fake',0.8,64)

# %% [markdown]
# ## Evaluating ViT_8Patch_Dino_224 model

# %%
activation = {}
def get_activation(name):
    def hook(model, input, output):
        activation[name] = output.detach()
    return hook

# %%
device = get_default_device()
model_dict_path = '/content/drive/MyDrive/vit_base_patch8_dino_224.pt'
model= torch.hub.load('facebookresearch/dino:main', 'dino_vitb8', pretrained=True)

for params in model.parameters():
  params.requires_grad = False
  
mlp = nn.Linear(768,2)
model = nn.Sequential(model,mlp)

model.load_state_dict(torch.load(model_dict_path))
model.to(device)


vit_8_model = model
vit_8_model[0].blocks[-1].attn.qkv.register_forward_hook(get_activation('qkv'))
img = Image.open("/content/real_vs_fake/real-vs-fake/test/fake/06TAEXDQGR.jpg")
transform = Compose([Resize(size=(224, 224)), ToTensor()])
x = transform(img)
x.size()
x = x.cuda()
logits = vit_8_model(x.unsqueeze(0))
att_mat = activation['qkv']
print(activation['qkv'].size())
input_expanded = activation['qkv'][0]
print(input_expanded.shape)
qkv = input_expanded.reshape(785, 3, 12, 768//12)
print("split qkv : ", qkv.shape)
q = qkv[:, 0].permute(1, 0, 2)  # (H=12, N=197, D/H=64)
k = qkv[:, 1].permute(1, 0, 2)  # (H=12, N=197, D/H=64)
kT = k.permute(0, 2, 1)  # (H=12, D/H=64, N=197)
print("transposed ks: ", kT.shape)
# Out:
# Downloading: "https://github.com/facebookresearch/dino/archive/main.zip" to /root/.cache/torch/hub/main.zip
# Downloading: "https://dl.fbaipublicfiles.com/dino/dino_vitbase8_pretrain/dino_vitbase8_pretrain.pth" to /root/.cache/torch/hub/checkpoints/dino_vitbase8_pretrain.pth
#   0%|          | 0.00/327M [00:00<?, ?B/s]
# torch.Size([1, 785, 2304])
# torch.Size([785, 2304])
# split qkv :  torch.Size([785, 3, 12, 64])
# transposed ks:  torch.Size([12, 64, 785])

# %%
# Attention Matrix
import matplotlib.pyplot as plt

attention_matrix = q @ kT
print("attention matrix: ", attention_matrix.shape)
plt.imshow(attention_matrix[3].detach().cpu().numpy())
# Out:
# attention matrix:  torch.Size([12, 785, 785])

# %%
# Visualize attention matrix
fig = plt.figure(figsize=(16, 8))
fig.suptitle("Visualização da Camada de Atenção - DINO8Pacthes", fontsize=24)
fig.add_axes()
img = np.asarray(img)
ax = fig.add_subplot(2, 4, 1)
ax.imshow(img)
for i in range(5,12):  # visualize the 100th rows of attention matrices in the 0-7th heads
    attn_heatmap = attention_matrix[i, -1, 1:].reshape((28, 28)).detach().cpu().numpy()
    ax = fig.add_subplot(2, 4, i-3)
    ax.imshow(attn_heatmap)

# %%
device = get_default_device()
test = DeviceDataLoader(test,device)
#valid = DeviceDataLoader(valid,device)

metrics,y_true,y_pred = evaluate(vit_8_model,test)
epoch_end(1,metrics)
# Out:
# Epoch [1], val_loss: 0.0640, val_acc: 0.9766

# %% [markdown]
# ### Confusion Matrix

# %%
classes = ('Falsa','Real')
cf_matrix = confusion_matrix(y_true, y_pred)
print(cf_matrix)
df_cm = pd.DataFrame(cf_matrix/np.sum(cf_matrix) , index = [i for i in classes],
                     columns = [i for i in classes])
plt.figure(figsize = (12,7))
sn.heatmap(df_cm, annot=True)

plt.show()
# Out:
# [[9792  208]
#  [ 260 9740]]

# %%
metrics = precision_recall_fscore_support(y_true,y_pred)
print("Precisão:")
print("0:", metrics[0][0],"1:",metrics[0][1])
print("Sensibilidade:")
print("0:", metrics[1][0],"1:",metrics[1][1])
print("F-Score")
print("0:", metrics[2][0],"1:",metrics[2][1])
print("Support")
print("0:", metrics[3][0],"1:",metrics[3][1])
# Out:
# Precisão:
# 0: 0.9741345005968961 1: 0.9790912746280659
# Sensibilidade:
# 0: 0.9792 1: 0.974
# F-Score
# 0: 0.9766606822262118 1: 0.9765390014036495
# Support
# 0: 10000 1: 10000

# %%
torch.cuda.empty_cache()

# %% [markdown]
# ## Evaluating ViT-16patch-DINO-224 Model

# %%
device = get_default_device()
model_dict_path = '/content/drive/MyDrive/vit_base_patch16_dino_224.pt'
model= torch.hub.load('facebookresearch/dino:main', 'dino_vitb16', pretrained=True)

for params in model.parameters():
  params.requires_grad = False
mlp = nn.Linear(768,2)
model = nn.Sequential(model,mlp)

model.load_state_dict(torch.load(model_dict_path))
model.to(device)

vit_16_model = model
vit_16_model[0].blocks[-1].attn.qkv.register_forward_hook(get_activation('qkv'))
img = Image.open("/content/real_vs_fake/real-vs-fake/test/fake/06TAEXDQGR.jpg")
transform = Compose([Resize(size=(224, 224)), ToTensor()])
x = transform(img)
x.size()
x = x.cuda()
logits = vit_16_model(x.unsqueeze(0))
att_mat = activation['qkv']
print(activation['qkv'].size())
input_expanded = activation['qkv'][0]
print(input_expanded.shape)
qkv = input_expanded.reshape(197, 3, 12, 768//12)
print("split qkv : ", qkv.shape)
q = qkv[:, 0].permute(1, 0, 2)  # (H=12, N=197, D/H=64)
k = qkv[:, 1].permute(1, 0, 2)  # (H=12, N=197, D/H=64)
kT = k.permute(0, 2, 1)  # (H=12, D/H=64, N=197)
print("transposed ks: ", kT.shape)
# Out:
# Using cache found in /root/.cache/torch/hub/facebookresearch_dino_main
# torch.Size([1, 197, 2304])
# torch.Size([197, 2304])
# split qkv :  torch.Size([197, 3, 12, 64])
# transposed ks:  torch.Size([12, 64, 197])

# %%
'''
Baseado no seguinte notebook :
https://colab.research.google.com/github/hirotomusiker/schwert_colab_data_storage/blob/master/notebook/Vision_Transformer_Tutorial.ipynb#scrollTo=elFemlXZXQ19
'''


# Attention Matrix
import matplotlib.pyplot as plt

attention_matrix = q @ kT
print("attention matrix: ", attention_matrix.shape)
plt.imshow(attention_matrix[9].detach().cpu().numpy())
# Out:
# attention matrix:  torch.Size([12, 197, 197])

# %%
# Visualize attention matrix
fig = plt.figure(figsize=(16, 8))
fig.suptitle("Visualização da Camada de Atenção - DINO16Pacthes", fontsize=24)
fig.add_axes()
img = np.asarray(img)
ax = fig.add_subplot(2, 4, 1)
ax.imshow(img)
for i in range(5,12):  # visualize the 100th rows of attention matrices in the 0-7th heads
    attn_heatmap = attention_matrix[i, -1, :-1].reshape((14, 14)).detach().cpu().numpy()
    ax = fig.add_subplot(2, 4, i-3)
    ax.imshow(attn_heatmap)

# %%
device = get_default_device()
test = DeviceDataLoader(test,device)
#valid = DeviceDataLoader(valid,device)

metrics,y_true,y_pred = evaluate(vit_16_model,test)
epoch_end(1,metrics)
# Out:
# Epoch [1], val_loss: 0.1494, val_acc: 0.9405

# %% [markdown]
# ### Confusion Matrix

# %%
classes = ('Falsa','Real')
cf_matrix = confusion_matrix(y_true, y_pred)
print(cf_matrix)
df_cm = pd.DataFrame(cf_matrix/np.sum(cf_matrix) , index = [i for i in classes],
                     columns = [i for i in classes])
plt.figure(figsize = (12,7))
sn.heatmap(df_cm, annot=True)

plt.show()
# Out:
# [[9423  577]
#  [ 614 9386]]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
metrics = precision_recall_fscore_support(y_true,y_pred)
print("Precisão:")
print("0:", metrics[0][0],"1:",metrics[0][1])
print("Sensibilidade:")
print("0:", metrics[1][0],"1:",metrics[1][1])
print("F-Score")
print("0:", metrics[2][0],"1:",metrics[2][1])
print("Support")
print("0:", metrics[3][0],"1:",metrics[3][1])
# Out:
# Precisão:
# 0: 0.9388263425326293 1: 0.9420857171534678
# Sensibilidade:
# 0: 0.9423 1: 0.9386
# F-Score
# 0: 0.940559964066477 1: 0.9403396283123777
# Support
# 0: 10000 1: 10000
